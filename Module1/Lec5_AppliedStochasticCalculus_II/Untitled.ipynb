# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('fivethirtyeight')

# %%
N = 1

mu = 0.1
S = 100
sigma = 0.2
dt = 0.01
randterm = np.random.randn(N)

# %%
dS = mu*S*dt + sigma * S * randterm * np.sqrt(dt)

# %% [markdown]
# let `randp = RAND()`, where RAND() in excel is uniformly distribute between [0,1]. We let `randp` be the value of c.d.f. of a random distribution.

# %%
np.random.uniform(0,1,N)
# Out:
# array([0.54024737])

# %%
def normal_dist(x, mu=0, sigma = 1):
    return 1/np.sqrt(2*np.pi* np.square(sigma) ) * np.exp(  np.square(x-mu)/(2*np.square(sigma)) )

# %%
x = np.linspace(-5,5,100)
y = normal_dist(x)

# %%
normal_dist(10)
# Out:
# 2.068398246784442e+21

# %%
plt.plot(x,y)
