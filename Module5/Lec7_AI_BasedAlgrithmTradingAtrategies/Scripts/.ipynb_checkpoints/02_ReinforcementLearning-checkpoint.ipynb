# %% [markdown]
# <img src='http://hilpisch.com/taim_logo.png' width="350px" align="right">

# %% [markdown]
# # Reinforcement Learning

# %% [markdown]
# &copy; Dr Yves J Hilpisch | The Python Quants GmbH
#
# http://aimachine.io | http://twitter.com/dyjh
#
# <img src="https://hilpisch.com/aiif_cover_shadow.png" width="300px" align="left">

# %% [markdown]
# ## Reinforcement Learning

# %%
import os
import math
import random
import numpy as np
import pandas as pd
from pylab import plt, mpl
plt.style.use('seaborn')
mpl.rcParams['font.family'] = 'serif'
np.set_printoptions(precision=4, suppress=True)
os.environ['PYTHONHASHSEED'] = '0'
# %config InlineBackend.figure_format = 'svg'

# %% [markdown]
# ## `CartPole` Environment

# %%
import gym

# %%
env = gym.make('CartPole-v1')

# %%
env.action_space.seed(100)
# Out:
# [100]

# %%
env.observation_space
# Out:
# Box([-4.8000e+00 -3.4028e+38 -4.1888e-01 -3.4028e+38], [4.8000e+00 3.4028e+38 4.1888e-01 3.4028e+38], (4,), float32)

# %%
env.observation_space.low.astype(np.float16)
# Out:
# array([-4.8  ,   -inf, -0.419,   -inf], dtype=float16)

# %%
env.observation_space.high.astype(np.float16)
# Out:
# array([4.8  ,   inf, 0.419,   inf], dtype=float16)

# %%
state = env.reset(seed=100)[0]

# %%
state
# Out:
# array([ 0.0335,  0.0097, -0.0211, -0.0457], dtype=float32)

# %%
env.action_space
# Out:
# Discrete(2)

# %%
env.action_space.n
# Out:
# 2

# %%
env.action_space.sample()
# Out:
# 1

# %%
env.action_space.sample()
# Out:
# 1

# %%
a = env.action_space.sample()
a
# Out:
# 0

# %%
state, reward, done, info, _ = env.step(a)
state, reward, done, info
# Out:
# (array([ 0.0337, -0.1852, -0.022 ,  0.2402], dtype=float32), 1.0, False, False)

# %%
env.reset(seed=100)
for e in range(1, 200):
    a = env.action_space.sample()
    state, reward, done, info, _ = env.step(a)
    print(f'step={e:2d} | state={state} | action={a} | reward={reward}')
    if done and (e + 1) < 200:
        print('*** FAILED ***')
        break
# Out:
# step= 1 | state=[ 0.0337  0.2051 -0.022  -0.345 ] | action=1 | reward=1.0
# step= 2 | state=[ 0.0378  0.0103 -0.0289 -0.0593] | action=0 | reward=1.0
# step= 3 | state=[ 0.038  -0.1844 -0.0301  0.2241] | action=0 | reward=1.0
# step= 4 | state=[ 0.0343 -0.3791 -0.0256  0.5071] | action=0 | reward=1.0
# step= 5 | state=[ 0.0267 -0.5739 -0.0155  0.7916] | action=0 | reward=1.0
# step= 6 | state=[ 0.0153 -0.3785  0.0003  0.4941] | action=1 | reward=1.0
# step= 7 | state=[ 0.0077 -0.1834  0.0102  0.2015] | action=1 | reward=1.0
# step= 8 | state=[ 0.004   0.0116  0.0143 -0.0879] | action=1 | reward=1.0
# step= 9 | state=[ 0.0042  0.2065  0.0125 -0.376 ] | action=1 | reward=1.0
# step=10 | state=[ 0.0084  0.0112  0.005  -0.0795] | action=0 | reward=1.0
# step=11 | state=[ 0.0086  0.2062  0.0034 -0.3706] | action=1 | reward=1.0
# step=12 | state=[ 0.0127  0.4013 -0.004  -0.6622] | action=1 | reward=1.0
# step=13 | state=[ 0.0207  0.5965 -0.0173 -0.9561] | action=1 | reward=1.0
# step=14 | state=[ 0.0327  0.4016 -0.0364 -0.6689] | action=0 | reward=1.0
# step=15 | state=[ 0.0407  0.5972 -0.0498 -0.9728] | action=1 | reward=1.0
# step=16 | state=[ 0.0527  0.793  -0.0692 -1.2807] | action=1 | reward=1.0
# step=17 | state=[ 0.0685  0.5988 -0.0948 -1.0105] | action=0 | reward=1.0
# step=18 | state=[ 0.0805  0.795  -0.115  -1.3314] | action=1 | reward=1.0
# step=19 | state=[ 0.0964  0.9914 -0.1417 -1.6577] | action=1 | reward=1.0
# step=20 | state=[ 0.1162  1.1879 -0.1748 -1.991 ] | action=1 | reward=1.0
# step=21 | state=[ 0.14    0.995  -0.2146 -1.7572] | action=0 | reward=1.0
# *** FAILED ***

# %%
done
# Out:
# True

# %% [markdown]
# ## Dimensionality Reduction

# %% [markdown]
# See http://kvfrans.com/simple-algoritms-for-solving-cartpole/.

# %%
np.random.seed(100)

# %%
weights = np.random.random(4) * 2 - 1

# %%
weights
# Out:
# array([ 0.0868, -0.4433, -0.151 ,  0.6896])

# %%
state = env.reset(seed=100)

# %%
state
# Out:
# (array([ 0.0335,  0.0097, -0.0211, -0.0457], dtype=float32), {})

# %%
s = np.dot(state[0], weights)
s
# Out:
# -0.029700348968367464

# %% [markdown]
# ## Action Rule

# %%
if s < 0:
    a = 0
else:
    a = 1

# %%
a
# Out:
# 0

# %% [markdown]
# ## Total Reward per Episode

# %%
def run_episode(env, weights):  
    state = env.reset()[0]
    treward = 0
    for _ in range(200):
        s = np.dot(state[0], weights)
        if s.all() < 0:
            a=0
        else:
            a=1
        state, reward, done, info, s_= env.step(a)
        treward += reward
        if done:
            break
    return treward

# %%
run_episode(env, weights)
# Out:
# 10.0

# %% [markdown]
# ## Simple Learning

# %%
def set_seeds(seed=100):
    random.seed(seed)
    np.random.seed(seed)

# %%
set_seeds()
num_episodes = 1000

# %%
besttreward = 0
for e in range(1, num_episodes + 1):
    weights = np.random.rand(4) * 2 - 1
    treward = run_episode(env, weights)
    if treward > besttreward:
        besttreward = treward
        bestweights = weights
        if treward == 200:
            print(f'SUCCESS | episode={e}')
            break
        print(f'UPDATE  | episode={e}')
# Out:
# UPDATE  | episode=1
# UPDATE  | episode=28

# %%
weights
# Out:
# array([ 0.6946,  0.5866, -0.3034,  0.9323])

# %% [markdown]
# ## Testing the Results

# %%
res = []
for _ in range(100):
    treward = run_episode(env, weights)
    res.append(treward)
res[:10]
# Out:
# [8.0, 9.0, 10.0, 9.0, 10.0, 9.0, 9.0, 9.0, 10.0, 8.0]

# %%
sum(res) / len(res)
# Out:
# 9.37

# %% [markdown]
# ## `TensorFlow/Keras`

# %%
import warnings as w
w.simplefilter('ignore')

# %%
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# %%
import tensorflow as tf

# %%
from tensorflow import keras
from keras.layers import Dense, Dropout
from keras.models import Sequential
from sklearn.metrics import accuracy_score

# %%
from tensorflow.python.framework.ops import disable_eager_execution
disable_eager_execution()

# %%
def set_seeds(seed=100):
    random.seed(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)
    env.action_space.seed(100)

# %% [markdown]
# ## Q-Learning

# %% [markdown]
# See https://keon.io/deep-q-learning/

# %%
from collections import deque

# %%
class DQLAgent:
    def __init__(self, gamma=0.95, hu=24, opt=keras.optimizers.Adam,
           lr=0.001, finish=False):
        self.finish = finish
        self.epsilon = 1.0
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995
        self.gamma = gamma
        self.batch_size = 32
        self.max_treward = 0
        self.averages = list()
        self.memory = deque(maxlen=2000)
        self.osn = env.observation_space.shape[0]
        self.model = self._build_model(hu, opt, lr)
        
    def _build_model(self, hu, opt, lr):
        model = Sequential()
        model.add(Dense(hu, input_dim=self.osn,
                        activation='relu'))
        model.add(Dense(hu, activation='relu'))
        model.add(Dense(env.action_space.n, activation='linear'))
        model.compile(loss='mse', optimizer=opt(learning_rate=lr))
        return model
        
    def act(self, state):
        if random.random() <= self.epsilon:
            return env.action_space.sample()
        action = self.model.predict(state)[0]
        return np.argmax(action)
    
    def replay(self):
        batch = random.sample(self.memory, self.batch_size)
        for state, action, reward, next_state, done in batch:
            if not done:
                reward += self.gamma * np.amax(
                    self.model.predict(next_state)[0])
            target = self.model.predict(state)
            target[0, action] = reward
            self.model.fit(state, target, epochs=1,
                           verbose=False)
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay
    
    def learn(self, episodes):
        trewards = []
        for e in range(1, episodes + 1):
            state = env.reset()[0]
            state = state.reshape(1,self.osn)
            for _ in range(5000):
                action = self.act(state)
                next_state, reward, done, info, s_ = env.step(action)
                next_state = np.reshape(next_state,
                                        [1, self.osn])
                self.memory.append([state, action, reward,
                                     next_state, done])
                state = next_state
                if done:
                    treward = _ + 1
                    trewards.append(treward)
                    av = sum(trewards[-25:]) / 25
                    self.averages.append(av)
                    self.max_treward = max(self.max_treward, treward)
                    templ = 'episode: {:4d}/{} | treward: {:4d} | '
                    templ += 'av: {:6.1f} | max: {:4d}'
                    print(templ.format(e, episodes, treward, av,
                                       self.max_treward), end='\r')
                    break
            if av > 195 and self.finish:
                break
            if len(self.memory) > self.batch_size:
                self.replay()
                
    def test(self, episodes):
        trewards = []
        for e in range(1, episodes + 1):
            state = env.reset()[0]
            for _ in range(5001):
                state = state.reshape(1,self.osn)
                action = np.argmax(self.model.predict(state)[0])
                next_state, reward, done, info, s_ = env.step(action)
                state = next_state
                if done:
                    treward = _ + 1
                    trewards.append(treward)
                    print('episode: {:4d}/{} | treward: {:4d}'
                          .format(e, episodes, treward), end='\r')
                    break
        return trewards
    
    def learnf(self, episodes):
        trewards = []
        for e in range(1, episodes + 1):
            state = env.reset().values
            state = state.reshape(1,self.osn)
            for _ in range(5000):
                action = self.act(state)
                next_state, reward, done, info = env.step(action)
                next_state = np.reshape(next_state,
                                        [1, self.osn])
                self.memory.append([state, action, reward,
                                     next_state, done])
                state = next_state
                if done:
                    treward = _ + 1
                    trewards.append(treward)
                    av = sum(trewards[-25:]) / 25
                    self.averages.append(av)
                    self.max_treward = max(self.max_treward, treward)
                    templ = 'episode: {:4d}/{} | treward: {:4d} | '
                    templ += 'av: {:6.1f} | max: {:4d}'
                    print(templ.format(e, episodes, treward, av,
                                       self.max_treward), end='\r')
                    break
            if av > 195 and self.finish:
                break
            if len(self.memory) > self.batch_size:
                self.replay()
                
    def testf(self, episodes):
        trewards = []
        for e in range(1, episodes + 1):
            state = env.reset().values
            for _ in range(5001):
                state = state.reshape(1,self.osn)
                action = np.argmax(self.model.predict(state)[0])
                next_state, reward, done, info = env.step(action)
                state = next_state
                if done:
                    treward = _ + 1
                    trewards.append(treward)
                    print('episode: {:4d}/{} | treward: {:4d}'
                          .format(e, episodes, treward), end='\r')
                    break
        return trewards

# %%
episodes = 1000

# %%
set_seeds(100)
agent = DQLAgent(finish=True)

# %%
agent.learn(episodes)
# Out:
# episode:  296/1000 | treward:  192 | av:  199.0 | max:  441

# %%
plt.figure(figsize=(10, 6))
x = range(len(agent.averages))
y = np.polyval(np.polyfit(x, agent.averages, deg=3), x)
plt.plot(agent.averages, label='moving average')
plt.plot(x, y, 'r--', label='trend')
plt.xlabel('episodes')
plt.ylabel('total reward')
plt.legend();

# %%
trewards = agent.test(100)
# Out:
# episode:  100/100 | treward:  191

# %%
sum(trewards) / len(trewards)
# Out:
# 206.29

# %% [markdown]
# ## Finance Environment

# %%
class observation_space:
    def __init__(self, n):
        self.shape = (n,)

# %%
class action_space:
    def __init__(self, n):
        self.n = n
    def seed(self, seed):
        random.seed(seed)
    def sample(self):
        return random.randint(0, self.n - 1)

# %%
class Finance:
    url = 'https://certificate.tpq.io/eod.csv'
    def __init__(self, symbol, features):
        self.symbol = symbol
        self.features = features
        self.observation_space = observation_space(4)
        self.osn = self.observation_space.shape[0]
        self.action_space = action_space(2)
        self.min_accuracy = 0.475
        self._get_data()
        self._prepare_data()
    def _get_data(self):
        self.raw = pd.read_csv(self.url, index_col=0,
                               parse_dates=True)
    def _prepare_data(self):
        self.data = pd.DataFrame(self.raw[self.symbol]).dropna()
        self.data['r'] = np.log(self.data / self.data.shift(1))
        self.data.dropna(inplace=True)
        self.data = (self.data - self.data.mean()) / self.data.std()
        self.data['d'] = np.where(self.data['r'] > 0, 1, 0)
    def _get_state(self):
        return self.data[self.features].iloc[
            self.bar - self.osn:self.bar].values
    def seed(self, seed=None):
        pass
    def reset(self):
        self.treward = 0
        self.accuracy = 0
        self.bar = self.osn
        state = self.data[self.features].iloc[
            self.bar - self.osn:self.bar]
        return state
    
    def step(self, action):
        correct = action == self.data['d'].iloc[self.bar]
        reward = 1 if correct else 0
        self.treward += reward
        self.bar += 1
        self.accuracy = self.treward / (self.bar - self.osn)
        if self.bar >= len(self.data):
            done = True
        elif reward == 1:
            done = False
        elif (self.accuracy < self.min_accuracy and
              self.bar > self.osn + 10):
            done = True
        else:
            done = False
        state = self._get_state()
        info = {}
        return state, reward, done, info

# %%
env = Finance('EUR=', 'r')

# %%
env.reset() # no sure is that a bug or not, when the environment setting is
# Out:
# Date
# 2012-04-03   -1.367772
# 2012-04-04   -1.440477
# 2012-04-05   -1.227039
# 2012-04-06    0.509107
# Name: r, dtype: float64

# %%
a = env.action_space.sample()
a
# Out:
# 0

# %%
env.step(a)
# Out:
# (array([-1.4405, -1.227 ,  0.5091,  0.1103]), 0, False, {})

# %%
set_seeds(100)
agent = DQLAgent(gamma=0.5, opt=keras.optimizers.RMSprop)

# %%
episodes = 300

# %%
agent.learnf(episodes)
# Out:
# episode:  300/300 | treward:   19 | av:  446.5 | max: 2602

# %%
agent.testf(3)
# Out:
# episode:    3/3 | treward:   34
# [34, 34, 34]

# %%
plt.figure(figsize=(10, 6))
x = range(len(agent.averages))
y = np.polyval(np.polyfit(x, agent.averages, deg=3), x)
plt.plot(agent.averages, label='moving average')
plt.plot(x, y, 'r--', label='regression')
plt.xlabel('episodes')
plt.ylabel('total reward')
plt.legend();

# %% [markdown]
# <img src="http://hilpisch.com/tpq_logo.png" alt="The Python Quants" width="35%" align="right" border="0"><br>
#
# <a href="http://tpq.io" target="_blank">http://tpq.io</a> | <a href="http://twitter.com/dyjh" target="_blank">@dyjh</a> | <a href="mailto:training@tpq.io">training@tpq.io</a>
